# %%
# %run shared_imports.py

# %%
engine = make_engine("settings.toml")
session = Session(engine)

# %%
steal_objectives = set()
round_dates = set()

for feedback in session.scalars(select(Feedback).filter(Feedback.key_name.endswith('_steal_objective'))).all():
    steal_objectives.update(feedback.keys())
    # print(sorted(feedback.keys()))
        # print(feedback.round)
        # round_dates.add(feedback.datetime)

#print(min(round_dates), max(round_dates))
steal_objectives
# Out:
# {'Steal ',
#  'Steal a functional AI',
#  'Steal a hand teleporter',
#  'Steal a supermatter sliver',
#  'Steal an ablative armor vest',
#  'Steal an ablative trenchcoat',
#  'Steal any set of secret documents of any organization',
#  'Steal any type of reactive armor',
#  'Steal championship belt',
#  'Steal grey slime extract',
#  'Steal the "Red" secret documents',
#  "Steal the Chief Medical Officer's hypospray",
#  "Steal the captain's Magnate MODsuit",
#  "Steal the captain's antique laser gun",
#  "Steal the captain's deluxe jetpack",
#  "Steal the captain's rapier",
#  "Steal the chief engineer's advanced magnetic boots",
#  "Steal the chief medical officer's advanced compact defibrillator",
#  "Steal the chief medical officer's advanced hypospray",
#  "Steal the head of security's X-01 multiphase energy gun",
#  'Steal the medal of captaincy',
#  'Steal the nuclear authentication disk',
#  "Steal the plutonium core from the station's nuclear device",
# ...
