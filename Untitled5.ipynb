# %%
# %run shared_imports.py

# %%
engine = make_engine("settings.toml")
session = Session(engine)

# %%
query = select(Feedback.json).join(Round).filter(
    or_(
        Feedback.key_name=='admin_verb',
    ),
    Feedback.datetime >= datetime(2023, 10, 25),
    Feedback.datetime <= datetime(2024, 10, 25),
)

df = pd.read_sql_query(query, session.connection())

# %%
used_verbs = set([x.replace('data.', '') for x in pd.json_normalize(df.json).columns])

# %%
used_verbs
# Out:
# {'Add Custom AI Law',
#  'Add Random AI Law',
#  'Admin PM Key',
#  'Admin PM Mob',
#  'Admin PM Name',
#  'Adminhelp',
#  'Advanced Proc-Call',
#  'Aghost',
#  'Announce',
#  'Aobserve',
#  'Asay',
#  'Assume Direct Control',
#  'Atom Proc-Call',
#  'Ban Panel',
#  'Big Brother Mode',
#  'CMA - Admin',
#  'CMA - Self',
#  'Call Shuttle',
#  'Camera Report',
#  'Cancel Shuttle',
#  'Change View Range',
#  'Check Antags',
#  'Check Contents',
#  'Create Comms Report',
#  'Create Crate',
#  'De-admin',
#  'Debug Space',
#  'Debug Verbs',
#  'Del Singulo/Tesla',
#  'Delay',
#  'Delete',
#  'Devsay',
#  'Direct Narrate',
#  'Drop Bomb',
#  'Drop Everything',
#  'Dsay',
#  'EMP',
#  'EXPL',
#  'End Round',
#  'Event Manager',
#  'Fax Panel',
#  'Game Panel',
#  'Get Key',
#  'Get Mob',
#  'Ghost Drag',
#  'Gib',
#  'Gibself',
#  'Give Disease',
#  'Give Spell',
#  'Global Narrate',
#  'Godmode',
#  'Hide Admin Verbs',
#  'Invisimin',
#  'Jump To Area',
#  'Jump To Coordinate',
# ...

# %%
all_verbs ={'Set Holiday': '/client/proc/Set_Holiday',
 'Call Shuttle': '/client/proc/admin_call_shuttle',
 'Cancel Shuttle': '/client/proc/admin_cancel_shuttle',
 'Toggle Deny Shuttle': '/client/proc/admin_deny_shuttle',
 'Aghost': '/client/proc/admin_ghost',
 'Aobserve': '/client/proc/admin_observe',
 'Adminhelp': '/client/proc/adminhelp',
 'Adminwho': '/client/proc/adminwho',
 'Ban Panel': '/client/proc/ban_panel',
 'Big Brother Mode': '/client/proc/big_brother',
 'Global Ban DB Lookup': '/client/proc/ccbdb_lookup_ckey',
 'Check AI Laws': '/client/proc/check_ai_laws',
 'Check Antagonists': '/client/proc/check_antagonists',
 'Add Custom AI law': '/client/proc/cmd_admin_add_freeform_ai_law',
 'Add Random AI Law': '/client/proc/cmd_admin_add_random_ai_law',
 'Send Alert Message': '/client/proc/cmd_admin_alert_message',
 'Make Alien': '/client/proc/cmd_admin_alienize',
 'Make Simple Animal': '/client/proc/cmd_admin_animalize',
 'Attack Log': '/client/proc/cmd_admin_attack_log',
 'Change Custom Event': '/client/proc/cmd_admin_change_custom_event',
 'Create Communications Report': '/client/proc/cmd_admin_create_centcom_report',
 'EM Pulse': '/client/proc/cmd_admin_emp',
 'Explosion': '/client/proc/cmd_admin_explosion',
 'Gib': '/client/proc/cmd_admin_gib',
 'Gibself': '/client/proc/cmd_admin_gib_self',
 'Godmode': '/client/proc/cmd_admin_godmode',
 'Grant Full Access': '/client/proc/cmd_admin_grantfullaccess',
 'List free slots': '/client/proc/cmd_admin_list_open_jobs',
 'Logging View': '/client/proc/cmd_admin_open_logging_view',
 'Admin PM Key': '/client/proc/cmd_admin_pm_by_key_panel',
 'Admin PM Name': '/client/proc/cmd_admin_pm_panel',
 'Prison': '/client/proc/cmd_admin_prison',
 'Make Robot': '/client/proc/cmd_admin_robotize',
 'Make slime': '/client/proc/cmd_admin_slimeize',
 'Make Superhero': '/client/proc/cmd_admin_super',
 'Global Narrate': '/client/proc/cmd_admin_world_narrate',
 'Assume direct control': '/client/proc/cmd_assume_direct_control',
 'Check New Players': '/client/proc/cmd_mentor_check_new_players',
 'Check Player Playtime': '/client/proc/cmd_mentor_check_player_exp',
 'Create Crate': '/client/proc/create_crate',
 'Create RnD Backup Restore Disk': '/client/proc/create_rnd_restore_disk',
 'De-admin self': '/client/proc/deadmin_self',
 'Drop Bomb': '/client/proc/drop_bomb',
 'Dsay': '/client/proc/dsay',
 'Economy Panel': '/client/proc/economy_manager',
 'Permissions Panel': '/client/proc/edit_admin_permissions',
 'Toggle AI Core Latejoin': '/client/proc/empty_ai_core_toggle_latejoin',
 'Event Manager Panel': '/client/proc/event_manager_panel',
 'Make Everyone Random': '/client/proc/everyone_random',
 'Export Character DMI/JSON': '/client/proc/export_current_character',
 'Fax Panel': '/client/proc/fax_panel',
 'Trigger Event': '/client/proc/forceEvent',
 'Free Job Slot': '/client/proc/free_slot',
 'Game Panel': '/client/proc/game_panel',
 'Get Server Logs': '/client/proc/getserverlogs',
 'Send Gimmick Team': '/client/proc/gimmick_team',
 'Give Disease': '/client/proc/give_disease',
 'Give Spell': '/client/proc/give_spell',
 'Man Up Global': '/client/proc/global_man_up',
 'Adminverbs - Hide All': '/client/proc/hide_verbs',
 'Investigate Round Objects': '/client/proc/investigate_show',
 'Invisimin': '/client/proc/invisimin',
 'Jump to...': '/client/proc/jump_to',
 'Manage Library': '/client/proc/library_manager',
 'List SSDs and AFKs': '/client/proc/list_ssds_afks',
 'Make pAI': '/client/proc/makepAI',
 'Manage Silicon Laws': '/client/proc/manage_silicon_laws',
 'Modify Station Goals': '/client/proc/modify_goals',
 'Create Antagonist': '/client/proc/one_click_antag',
 'Open Admin Ticket Interface': '/client/proc/openAdminTicketUI',
 'My Admin Tickets': '/client/proc/openAdminUserUI',
 'Open Mentor Ticket Interface': '/client/proc/openMentorTicketUI',
 'My Mentor Tickets': '/client/proc/openMentorUserUI',
 'Outfit Manager': '/client/proc/outfit_manager',
 'Ping all admins': '/client/proc/ping_all_admins',
 'Play Sound via Intercomms': '/client/proc/play_intercomm_sound',
 'Play Local Sound': '/client/proc/play_local_sound',
 'Play Server Sound': '/client/proc/play_server_sound',
 'Play Global Sound': '/client/proc/play_sound',
 'Player Panel': '/client/proc/player_panel_new',
 'Re-admin self': '/client/proc/readmin',
 'Reset NTTC Configuration': '/client/proc/reset_all_tcs',
 'Respawn Character': '/client/proc/respawn_character',
 'Dispatch CentComm Response Team': '/client/proc/response_team',
 'Secrets': '/client/proc/secrets',
 'Send Mob': '/client/proc/sendmob',
 'Show Custom Tip': '/client/proc/show_tip',
 'Adminverbs - Show': '/client/proc/show_verbs',
 'Show Watchlist': '/client/proc/show_watchlist',
 'Start Vote': '/client/proc/start_vote',
 'Stealth Mode': '/client/proc/stealth',
 'Stop Global Admin Sounds': '/client/proc/stop_global_admin_sounds',
 'Send Syndicate Infiltration Team': '/client/proc/syndicate_infiltration_team',
 'Spawn Syndicate Strike Team': '/client/proc/syndicate_strike_team',
 'Toggle Advanced Admin Interaction': '/client/proc/toggle_advanced_interaction',
 'Toggle ERT': '/client/proc/toggle_ert_calling',
 'Toggle random events on/off': '/client/proc/toggle_random_events',
 'Change View Range': '/client/proc/toggle_view_range',
 'Toggle Build Mode Self': '/client/proc/togglebuildmodeself',
 'Create AI Triumvirate': '/client/proc/triple_ai',
 'Asays': '/client/proc/view_asays',
 'Devsays': '/client/proc/view_devsays',
 'Msays': '/client/proc/view_msays',
 'Player Notes': '/datum/admins/proc/PlayerNotes',
 'Announce': '/datum/admins/proc/announce',
 'Show Player Notes': '/datum/admins/proc/show_player_notes',
 'Show Traitor Panel': '/datum/admins/proc/show_traitor_panel',
 'Modify Station Traits': '/datum/admins/proc/station_traits_panel',
 'Toggle AI': '/datum/admins/proc/toggleAI',
 'VPN Ckey Whitelist': '/datum/admins/proc/vpn_whitelist'}

# %%
all_verb_names = set(all_verbs.keys())

# %%
sorted(all_verb_names)
# Out:
# ['Add Custom AI law',
#  'Add Random AI Law',
#  'Admin PM Key',
#  'Admin PM Name',
#  'Adminhelp',
#  'Adminverbs - Hide All',
#  'Adminverbs - Show',
#  'Adminwho',
#  'Aghost',
#  'Announce',
#  'Aobserve',
#  'Asays',
#  'Assume direct control',
#  'Attack Log',
#  'Ban Panel',
#  'Big Brother Mode',
#  'Call Shuttle',
#  'Cancel Shuttle',
#  'Change Custom Event',
#  'Change View Range',
#  'Check AI Laws',
#  'Check Antagonists',
#  'Check New Players',
#  'Check Player Playtime',
#  'Create AI Triumvirate',
#  'Create Antagonist',
#  'Create Communications Report',
#  'Create Crate',
#  'Create RnD Backup Restore Disk',
#  'De-admin self',
#  'Devsays',
#  'Dispatch CentComm Response Team',
#  'Drop Bomb',
#  'Dsay',
#  'EM Pulse',
#  'Economy Panel',
#  'Event Manager Panel',
#  'Explosion',
#  'Export Character DMI/JSON',
#  'Fax Panel',
#  'Free Job Slot',
#  'Game Panel',
#  'Get Server Logs',
#  'Gib',
#  'Gibself',
#  'Give Disease',
#  'Give Spell',
# ...

# %%
used_verbs
# Out:
# {'Add Custom AI Law',
#  'Add Random AI Law',
#  'Admin PM Key',
#  'Admin PM Mob',
#  'Admin PM Name',
#  'Adminhelp',
#  'Advanced Proc-Call',
#  'Aghost',
#  'Announce',
#  'Aobserve',
#  'Asay',
#  'Assume Direct Control',
#  'Atom Proc-Call',
#  'Ban Panel',
#  'Big Brother Mode',
#  'CMA - Admin',
#  'CMA - Self',
#  'Call Shuttle',
#  'Camera Report',
#  'Cancel Shuttle',
#  'Change View Range',
#  'Check Antags',
#  'Check Contents',
#  'Create Comms Report',
#  'Create Crate',
#  'De-admin',
#  'Debug Space',
#  'Debug Verbs',
#  'Del Singulo/Tesla',
#  'Delay',
#  'Delete',
#  'Devsay',
#  'Direct Narrate',
#  'Drop Bomb',
#  'Drop Everything',
#  'Dsay',
#  'EMP',
#  'EXPL',
#  'End Round',
#  'Event Manager',
#  'Fax Panel',
#  'Game Panel',
#  'Get Key',
#  'Get Mob',
#  'Ghost Drag',
#  'Gib',
#  'Gibself',
#  'Give Disease',
#  'Give Spell',
#  'Global Narrate',
#  'Godmode',
#  'Hide Admin Verbs',
#  'Invisimin',
#  'Jump To Area',
#  'Jump To Coordinate',
# ...

# %%
all_verb_names - used_verbs
# Out:
# {'Add Custom AI law',
#  'Adminverbs - Hide All',
#  'Adminverbs - Show',
#  'Adminwho',
#  'Asays',
#  'Assume direct control',
#  'Attack Log',
#  'Change Custom Event',
#  'Check AI Laws',
#  'Check Antagonists',
#  'Check New Players',
#  'Check Player Playtime',
#  'Create AI Triumvirate',
#  'Create Antagonist',
#  'Create Communications Report',
#  'Create RnD Backup Restore Disk',
#  'De-admin self',
#  'Devsays',
#  'Dispatch CentComm Response Team',
#  'EM Pulse',
#  'Economy Panel',
#  'Event Manager Panel',
#  'Explosion',
#  'Export Character DMI/JSON',
#  'Free Job Slot',
#  'Get Server Logs',
#  'Global Ban DB Lookup',
#  'Grant Full Access',
#  'Investigate Round Objects',
#  'Jump to...',
#  'List SSDs and AFKs',
#  'List free slots',
#  'Logging View',
#  'Make Everyone Random',
#  'Make Robot',
#  'Make Simple Animal',
#  'Make Superhero',
#  'Make pAI',
#  'Make slime',
#  'Man Up Global',
#  'Manage Library',
#  'Modify Station Goals',
# ...
