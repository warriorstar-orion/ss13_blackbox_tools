# %%
from model import Round
from sqlalchemy import select
from sqlalchemy.orm import Session
from sqlalchemy import create_engine

engine = create_engine("mysql+mysqldb://root@localhost/parastats_prod")

# %%
from collections import defaultdict

r_count = 0
total_count = 0

items = defaultdict(int)
with Session(engine) as session:
    for r in session.execute(select(Round).order_by(Round.id)).scalars():
        total_count += 1
        if r.game_mode == "nuclear emergency":
            if r.has_feedback_stat("traitor_uplink_items_bought"):
                uplink_items =r.get_feedback_stat("traitor_uplink_items_bought")
                for item in uplink_items:
                    items[item] += 1     
                r_count += 1

# %%
total_count
# Out:
# 1216

# %%
r_count
# Out:
# 68

# %%
for k, v in items.items():
    print(f"{k},{v}")
# Out:
# Elite Syndicate MODsuit,64
# Adrenal Bio-chip,66
# Shielded Hardsuit,39
# MODsuit Thermal Visor Module,25
# Cryptographic Sequencer,65
# Energy Sword,54
# C-20r Bundle,30
# Chainsaw,44
# Rocket Launcher,16
# Power Fist,16
# Hardened Reviver Implant,37
# Syndicate Combat Medic Kit,58
# Hardened CNS Rebooter Implant,33
# C-20r - .45 Ammo Duffel Bag,15
# X-Ray Vision Implant,56
# Syndicate Saboteur Cyborg,23
# Medical Bundle,23
# Combat defibrillator module,10
# Composition C-4,16
# 12g Meteorslug Shells,15
# Bulldog - 12g XL Magazine Duffel Bag,4
# Bulldog - 12g Slug Magazine,18
# Universal Suppressor,8
# Binary Translator Key,5
# Raw Telecrystal,42
# 5 Raw Telecrystals,35
# Rocket Launcher Shell,14
# Access Tuner,12
# Thermal Vision Implant,33
# Freedom Bio-chip,36
# Stealth Bio-chip,38
# Bag of X-4 explosives,9
# Sniper bundle,16
# Energy Dagger,8
# C-20r Submachine Gun,33
# Grenadier's belt,20
# Macrobomb Bio-chip,23
# Nuclear Uplink Bio-chip,2
# 50 Raw Telecrystals,7
# No-Slip Chameleon Shoes,19
# Sniper - .50 Antimatter Magazine,22
# Sniper - .50 Penetrator Magazine,16
# Stechkin - 10mm Magazine,30
# Syndicate Detonator,1
# Syndicate Bomb,16
# MODsuit Anti-Slip Module,29
# Syndicate Medical Cyborg,29
# C-20r - .45 Magazine,36
# Pack of 5 Fragmentation Grenades,17
# Chameleon Kit,16
# Pizza Bomb,1
# Bulldog - 12g Ammo Duffel Bag,5
# Syndicate Cyborg Upgrade Module (VTEC),34
# Syndicate Space Suit,12
# CQC Manual,23
# Fiber Wire Garrote,1
# Viscerator Delivery Grenade,14
# Microbomb Bio-chip,14
# L6 Squad Automatic Weapon,14
# L6 SAW - 5.56x45mm Box Magazine,12
# M-90gl Carbine,20
# Carbine - 5.56 Toploader Magazine,18
# Fragmentation Grenade,15
# FK-69 Pistol Kit,5
# Box of Throwing Weapons,2
# Syndicate Assault Cyborg,12
# Gloves of the North Star,8
# Cybernetic Implants Bundle,8
# Prototype Nanite Autoinjector Kit,15
# Sniper - .50 Magazine,6
# Pack of 5 C-4 Explosives,18
# Sniper Rifle,22
# Detomatix PDA Cartridge,8
# Fully Loaded Toolbox,8
# Advanced Pinpointer,5
# Agent ID Card,7
# Chameleon-Projector,9
# Syndicate Minibomb,17
# Camera Flash,6
# Heavily Modified Springlock MODsuit Module,2
# Stechkin - 10mm Incendiary Magazine,6
# MODsuit Night Visor Module,4
# Stechkin - 10mm Armour Piercing Magazine,12
# EMP Grenades and bio-chip implanter Kit,12
# Plasma Fire Grenades,5
# Syndicate Briefcase Full of Cash,2
# Syndicate .357 Revolver,7
# Medbeam Gun,10
# EMP Flashlight,2
# Storage Bio-chip,2
# Gygax Exosuit,6
# Nuclear party pack,4
# Carbine - 40mm Grenade Ammo Box,8
# Prototype Freedom Bio-chip,4
# Experimental Syndicate Teleporter,8
# Assault Pod Targetting Device,5
# Energy Shield,10
# Mind Batterer,13
# Syndicate Soap,2
# Stechkin - 10mm Hollow Point Magazine,4
# Thermal Chameleon Glasses,2
# Bulldog Bundle,10
# Bulldog - 12g Buckshot Magazine,14
# Hidden Holster Module,4
# Toy Machine Gun,3
# Box of Riot Darts,3
# Reinforcement,12
# 20 Raw Telecrystals,11
# Camera Bug,6
# Radio Jammer,4
# .357 Revolver - Speedloader,6
# Power Sink,3
# Hacked AI Upload Module,4
# Combat Defibrillator Module,15
# Bag of C-4 explosives,4
# Stechkin APS - 10mm Magazine,3
# Chameleon Security HUD,1
# Syndicate Encryption Key,3
# Krav Maga Implant,13
# Blood-Red Magboots,5
# Sniper - .50 Haemorrhage Magazine,2
# Composition X-4,5
# Flamethrower,7
# Stechkin APS Pistol,2
# Syndicate Bomber Jacket,3
# Trick Revolver,1
# Chameleon Counterfeiter,1
# Rapid Syringe Gun,1
# Honk Brand Infiltration Kit,5
# Mindslave Bio-chip,6
# Knockout Gas Grenades,6
# 100 Raw Telecrystals,3
# Bulldog - 12g Dragon's Breath Magazine,4
# Mauler Exosuit,1
# Toy Submachine Gun,2
# DNA Scrambler,1
# Hand Held Mirror,2
# Stechkin APS - 10mm Armour Piercing Magazine,1
# Syndicate Smokes,1
# Sniper - .50 Soporific Magazine,2
# MODsuit Plate Compression Module,1
# Stechkin APS - 10mm Incendiary Magazine,1

# %%
r = Round.get('31768')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 r = Round.get('31768')
#
# AttributeError: type object 'Round' has no attribute 'get'
